# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error
from codecarbon import EmissionsTracker
from eco2ai import Tracker

sys.path.append(os.path.abspath(".."))

import imputation as imp
import forecasting as fc

# %%
df = pd.read_csv("datasets/uci/uci_60min.csv")
df = df.select_dtypes(include="number")
df.head()
# Out:
#    Global_active_power  Global_reactive_power     Voltage  Global_intensity  \
# 0             4.222889               0.229000  234.643889         18.100000
# 1             3.632200               0.080033  234.580167         15.600000
# 2             3.400233               0.085233  233.232500         14.503333
# 3             3.268567               0.075100  234.071500         13.916667
# 4             3.056467               0.076667  237.158667         13.046667
#
#    Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0             0.0        0.527778       16.861111
# 1             0.0        6.716667       16.866667
# 2             0.0        1.433333       16.683333
# 3             0.0        0.000000       16.783333
# 4             0.0        0.416667       17.216667

# %%
imputation_methods = {
    "LOCF": imp.locf,
    "NOCB": imp.nocb,
    "Linear Interpolation": imp.linear_interpolation,
    "Linear Regression": imp.linear_regression,
    "K-Nearest Neighbor": imp.knn,
    "MICE": imp.mice,
    "LightGBM": imp.lightgbm,
}
target = "Global_active_power"

imputed = {}
performance = {}
df_masked, samples = imp.create_mcar_data(df, missing=0.2, seed=42)

for n, f in imputation_methods.items():
    cc_tracker = EmissionsTracker(
        project_name=n,
        output_dir="performance/results",
        output_file="uci_codecarbon.csv",
    )
    eco_tracker = Tracker(project_name=n, file_name="performance/results/uci_eco2ai.csv")

    # Start time and emission trackers
    cc_tracker.start()
    eco_tracker.start()

    df_imputed = f(df_masked.copy())

    # Stop trackers
    emissions = cc_tracker.stop()
    eco_tracker.stop()

    # Store imputed data in dictionary
    imputed[n] = df_imputed

    # Get error metrics only for the masked values
    i = df.columns.get_loc(target)
    mask = samples[:, i]
    y_true = df.values[:, i][mask]
    y_pred = df_imputed.values[:, i][mask]

    valid = (~np.isnan(y_true)) & (~np.isnan(y_pred))
    y_true = y_true[valid]
    y_pred = y_pred[valid]

    # Compute error
    mae = mean_absolute_error(y_true, y_pred)
    nrmse = root_mean_squared_error(y_true, y_pred) / (np.max(y_true) - np.min(y_true))

    performance[n] = {
        "MAE": mae,
        "NRMSE": nrmse,
    }
# Out:
# [codecarbon WARNING @ 16:13:25] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 16:13:25] [setup] RAM Tracking...
# [codecarbon INFO @ 16:13:25] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:13:26] We saw that you have a AMD Ryzen 5 7530U with Radeon Graphics but we don't know it. Please contact us.
# [codecarbon WARNING @ 16:13:26] We will use the default power consumption of 4 W per thread for your 12 CPU, so 48W.
# [codecarbon WARNING @ 16:13:26] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 16:13:26] CPU Model on constant consumption mode: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon WARNING @ 16:13:26] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 16:13:26] [setup] GPU Tracking...
# [codecarbon INFO @ 16:13:26] No GPU found.
# [codecarbon INFO @ 16:13:26] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 16:13:26] >>> Tracker's metadata:
# [codecarbon INFO @ 16:13:26]   Platform system: Linux-6.8.0-60-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 16:13:26]   Python version: 3.12.3
# [codecarbon INFO @ 16:13:26]   CodeCarbon version: 3.0.1
# [codecarbon INFO @ 16:13:26]   Available RAM : 13.501 GB
# [codecarbon INFO @ 16:13:26]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 16:13:26]   CPU model: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon INFO @ 16:13:26]   GPU count: None
# [codecarbon INFO @ 16:13:26]   GPU model: None
# [codecarbon INFO @ 16:13:30] Emissions data (if any) will be saved to file /home/milou/Documents/afstudeerproject/performance/results/uci_codecarbon.csv
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:140: UserWarning:
# If you use a VPN, you may have problems with identifying your country by IP.
# It is recommended to disable VPN or
# manually set up the ISO-Alpha-2 code of your country during initialization of the Tracker() class.
# You can find the ISO-Alpha-2 code of your country here: https://www.iban.com/country-codes
#
#   warnings.warn(
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/tools/tools_gpu.py:42: NoGPUWarning: There is no any available GPU devices or your GPU is not supported by Nvidia library!
# The tracker will consider CPU usage only
#   warnings.warn(
# [codecarbon INFO @ 16:13:31] Energy consumed for RAM : 0.000005 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:13:32] Delta energy consumed for CPU with cpu_load : 0.000002 kWh, power : 4.800000000000001 W
# [codecarbon INFO @ 16:13:32] Energy consumed for All CPU : 0.000002 kWh
# [codecarbon INFO @ 16:13:32] 0.000007 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7799067497253418' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.971014087814638e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.768101592472418e-09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon WARNING @ 16:13:32] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 16:13:32] [setup] RAM Tracking...
# [codecarbon INFO @ 16:13:32] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:13:33] We saw that you have a AMD Ryzen 5 7530U with Radeon Graphics but we don't know it. Please contact us.
# [codecarbon WARNING @ 16:13:33] We will use the default power consumption of 4 W per thread for your 12 CPU, so 48W.
# [codecarbon WARNING @ 16:13:33] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 16:13:33] CPU Model on constant consumption mode: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon WARNING @ 16:13:33] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 16:13:33] [setup] GPU Tracking...
# [codecarbon INFO @ 16:13:33] No GPU found.
# [codecarbon INFO @ 16:13:33] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 16:13:33] >>> Tracker's metadata:
# [codecarbon INFO @ 16:13:33]   Platform system: Linux-6.8.0-60-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 16:13:33]   Python version: 3.12.3
# [codecarbon INFO @ 16:13:33]   CodeCarbon version: 3.0.1
# [codecarbon INFO @ 16:13:33]   Available RAM : 13.501 GB
# [codecarbon INFO @ 16:13:33]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 16:13:33]   CPU model: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon INFO @ 16:13:33]   GPU count: None
# [codecarbon INFO @ 16:13:33]   GPU model: None
# [codecarbon INFO @ 16:13:36] Emissions data (if any) will be saved to file /home/milou/Documents/afstudeerproject/performance/results/uci_codecarbon.csv
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:140: UserWarning:
# If you use a VPN, you may have problems with identifying your country by IP.
# It is recommended to disable VPN or
# manually set up the ISO-Alpha-2 code of your country during initialization of the Tracker() class.
# You can find the ISO-Alpha-2 code of your country here: https://www.iban.com/country-codes
#
#   warnings.warn(
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/tools/tools_gpu.py:42: NoGPUWarning: There is no any available GPU devices or your GPU is not supported by Nvidia library!
# The tracker will consider CPU usage only
#   warnings.warn(
# [codecarbon INFO @ 16:13:38] Energy consumed for RAM : 0.000005 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:13:39] Delta energy consumed for CPU with cpu_load : 0.000002 kWh, power : 4.800000000000001 W
# [codecarbon INFO @ 16:13:39] Energy consumed for All CPU : 0.000002 kWh
# [codecarbon INFO @ 16:13:39] 0.000007 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7753257751464844' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.001284053221752e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.887400672035973e-09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon WARNING @ 16:13:39] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 16:13:39] [setup] RAM Tracking...
# [codecarbon INFO @ 16:13:39] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:13:40] We saw that you have a AMD Ryzen 5 7530U with Radeon Graphics but we don't know it. Please contact us.
# [codecarbon WARNING @ 16:13:40] We will use the default power consumption of 4 W per thread for your 12 CPU, so 48W.
# [codecarbon WARNING @ 16:13:40] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 16:13:40] CPU Model on constant consumption mode: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon WARNING @ 16:13:40] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 16:13:40] [setup] GPU Tracking...
# [codecarbon INFO @ 16:13:40] No GPU found.
# [codecarbon INFO @ 16:13:40] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 16:13:40] >>> Tracker's metadata:
# [codecarbon INFO @ 16:13:40]   Platform system: Linux-6.8.0-60-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 16:13:40]   Python version: 3.12.3
# [codecarbon INFO @ 16:13:40]   CodeCarbon version: 3.0.1
# [codecarbon INFO @ 16:13:40]   Available RAM : 13.501 GB
# [codecarbon INFO @ 16:13:40]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 16:13:40]   CPU model: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon INFO @ 16:13:40]   GPU count: None
# [codecarbon INFO @ 16:13:40]   GPU model: None
# [codecarbon INFO @ 16:13:43] Emissions data (if any) will be saved to file /home/milou/Documents/afstudeerproject/performance/results/uci_codecarbon.csv
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:140: UserWarning:
# If you use a VPN, you may have problems with identifying your country by IP.
# It is recommended to disable VPN or
# manually set up the ISO-Alpha-2 code of your country during initialization of the Tracker() class.
# You can find the ISO-Alpha-2 code of your country here: https://www.iban.com/country-codes
#
#   warnings.warn(
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/tools/tools_gpu.py:42: NoGPUWarning: There is no any available GPU devices or your GPU is not supported by Nvidia library!
# The tracker will consider CPU usage only
#   warnings.warn(
# [codecarbon INFO @ 16:13:45] Energy consumed for RAM : 0.000005 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:13:46] Delta energy consumed for CPU with cpu_load : 0.000002 kWh, power : 4.800000000000001 W
# [codecarbon INFO @ 16:13:46] Energy consumed for All CPU : 0.000002 kWh
# [codecarbon INFO @ 16:13:46] 0.000007 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7839460372924805' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.062023895632592e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.126786716750304e-09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon WARNING @ 16:13:46] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 16:13:46] [setup] RAM Tracking...
# [codecarbon INFO @ 16:13:46] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:13:47] We saw that you have a AMD Ryzen 5 7530U with Radeon Graphics but we don't know it. Please contact us.
# [codecarbon WARNING @ 16:13:47] We will use the default power consumption of 4 W per thread for your 12 CPU, so 48W.
# [codecarbon WARNING @ 16:13:47] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 16:13:47] CPU Model on constant consumption mode: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon WARNING @ 16:13:47] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 16:13:47] [setup] GPU Tracking...
# [codecarbon INFO @ 16:13:47] No GPU found.
# [codecarbon INFO @ 16:13:47] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 16:13:47] >>> Tracker's metadata:
# [codecarbon INFO @ 16:13:47]   Platform system: Linux-6.8.0-60-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 16:13:47]   Python version: 3.12.3
# [codecarbon INFO @ 16:13:47]   CodeCarbon version: 3.0.1
# [codecarbon INFO @ 16:13:47]   Available RAM : 13.501 GB
# [codecarbon INFO @ 16:13:47]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 16:13:47]   CPU model: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon INFO @ 16:13:47]   GPU count: None
# [codecarbon INFO @ 16:13:47]   GPU model: None
# [codecarbon INFO @ 16:13:50] Emissions data (if any) will be saved to file /home/milou/Documents/afstudeerproject/performance/results/uci_codecarbon.csv
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:140: UserWarning:
# If you use a VPN, you may have problems with identifying your country by IP.
# It is recommended to disable VPN or
# manually set up the ISO-Alpha-2 code of your country during initialization of the Tracker() class.
# You can find the ISO-Alpha-2 code of your country here: https://www.iban.com/country-codes
#
#   warnings.warn(
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/tools/tools_gpu.py:42: NoGPUWarning: There is no any available GPU devices or your GPU is not supported by Nvidia library!
# The tracker will consider CPU usage only
#   warnings.warn(
# [codecarbon INFO @ 16:13:52] Energy consumed for RAM : 0.000005 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:13:53] Delta energy consumed for CPU with cpu_load : 0.000002 kWh, power : 4.800000000000001 W
# [codecarbon INFO @ 16:13:53] Energy consumed for All CPU : 0.000002 kWh
# [codecarbon INFO @ 16:13:53] 0.000007 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8250977993011475' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.199348090385911e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.66800471338624e-09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon WARNING @ 16:13:53] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 16:13:53] [setup] RAM Tracking...
# [codecarbon INFO @ 16:13:53] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:13:54] We saw that you have a AMD Ryzen 5 7530U with Radeon Graphics but we don't know it. Please contact us.
# [codecarbon WARNING @ 16:13:54] We will use the default power consumption of 4 W per thread for your 12 CPU, so 48W.
# [codecarbon WARNING @ 16:13:54] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 16:13:54] CPU Model on constant consumption mode: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon WARNING @ 16:13:54] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 16:13:54] [setup] GPU Tracking...
# [codecarbon INFO @ 16:13:54] No GPU found.
# [codecarbon INFO @ 16:13:54] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 16:13:54] >>> Tracker's metadata:
# [codecarbon INFO @ 16:13:54]   Platform system: Linux-6.8.0-60-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 16:13:54]   Python version: 3.12.3
# [codecarbon INFO @ 16:13:54]   CodeCarbon version: 3.0.1
# [codecarbon INFO @ 16:13:54]   Available RAM : 13.501 GB
# [codecarbon INFO @ 16:13:54]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 16:13:54]   CPU model: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon INFO @ 16:13:54]   GPU count: None
# [codecarbon INFO @ 16:13:54]   GPU model: None
# [codecarbon INFO @ 16:13:57] Emissions data (if any) will be saved to file /home/milou/Documents/afstudeerproject/performance/results/uci_codecarbon.csv
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:140: UserWarning:
# If you use a VPN, you may have problems with identifying your country by IP.
# It is recommended to disable VPN or
# manually set up the ISO-Alpha-2 code of your country during initialization of the Tracker() class.
# You can find the ISO-Alpha-2 code of your country here: https://www.iban.com/country-codes
#
#   warnings.warn(
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/tools/tools_gpu.py:42: NoGPUWarning: There is no any available GPU devices or your GPU is not supported by Nvidia library!
# The tracker will consider CPU usage only
#   warnings.warn(
# [codecarbon INFO @ 16:14:13] Energy consumed for RAM : 0.000043 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:14:14] Delta energy consumed for CPU with cpu_load : 0.000081 kWh, power : 18.9024 W
# [codecarbon INFO @ 16:14:14] Energy consumed for All CPU : 0.000081 kWh
# [codecarbon INFO @ 16:14:14] 0.000124 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.232036590576172' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.812036755838932e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1082714901009723e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon INFO @ 16:14:28] Energy consumed for RAM : 0.000083 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:14:29] Delta energy consumed for CPU with cpu_load : 0.000064 kWh, power : 15.989999999999997 W
# [codecarbon INFO @ 16:14:29] Energy consumed for All CPU : 0.000146 kWh
# [codecarbon INFO @ 16:14:29] 0.000229 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30.22959327697754' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.350827319182236e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3206180105541453e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '40.47323393821716' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.5709816095749685e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.195618559020858e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon INFO @ 16:14:43] Energy consumed for RAM : 0.000124 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:14:44] Delta energy consumed for CPU with cpu_load : 0.000065 kWh, power : 16.098 W
# [codecarbon INFO @ 16:14:44] Energy consumed for All CPU : 0.000211 kWh
# [codecarbon INFO @ 16:14:44] 0.000334 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '50.23141050338745' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.157930610704224e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.4269451384989168e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon INFO @ 16:14:54] Energy consumed for RAM : 0.000154 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:14:55] Delta energy consumed for CPU with cpu_load : 0.000038 kWh, power : 12.49846153846154 W
# [codecarbon INFO @ 16:14:55] Energy consumed for All CPU : 0.000248 kWh
# [codecarbon INFO @ 16:14:55] 0.000402 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '55.97856378555298' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.177481952807555e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.4346506547946553e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '56.00839877128601' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.177481952807555e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.4346506547946553e-05' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon WARNING @ 16:14:55] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 16:14:55] [setup] RAM Tracking...
# [codecarbon INFO @ 16:14:55] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:14:56] We saw that you have a AMD Ryzen 5 7530U with Radeon Graphics but we don't know it. Please contact us.
# [codecarbon WARNING @ 16:14:56] We will use the default power consumption of 4 W per thread for your 12 CPU, so 48W.
# [codecarbon WARNING @ 16:14:56] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 16:14:56] CPU Model on constant consumption mode: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon WARNING @ 16:14:56] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 16:14:56] [setup] GPU Tracking...
# [codecarbon INFO @ 16:14:56] No GPU found.
# [codecarbon INFO @ 16:14:56] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 16:14:56] >>> Tracker's metadata:
# [codecarbon INFO @ 16:14:56]   Platform system: Linux-6.8.0-60-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 16:14:56]   Python version: 3.12.3
# [codecarbon INFO @ 16:14:56]   CodeCarbon version: 3.0.1
# [codecarbon INFO @ 16:14:56]   Available RAM : 13.501 GB
# [codecarbon INFO @ 16:14:56]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 16:14:56]   CPU model: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon INFO @ 16:14:56]   GPU count: None
# [codecarbon INFO @ 16:14:56]   GPU model: None
# [codecarbon INFO @ 16:15:00] Emissions data (if any) will be saved to file /home/milou/Documents/afstudeerproject/performance/results/uci_codecarbon.csv
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:140: UserWarning:
# If you use a VPN, you may have problems with identifying your country by IP.
# It is recommended to disable VPN or
# manually set up the ISO-Alpha-2 code of your country during initialization of the Tracker() class.
# You can find the ISO-Alpha-2 code of your country here: https://www.iban.com/country-codes
#
#   warnings.warn(
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/tools/tools_gpu.py:42: NoGPUWarning: There is no any available GPU devices or your GPU is not supported by Nvidia library!
# The tracker will consider CPU usage only
#   warnings.warn(
# [codecarbon INFO @ 16:15:02] Energy consumed for RAM : 0.000005 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:15:02] Delta energy consumed for CPU with cpu_load : 0.000004 kWh, power : 8.088000000000001 W
# [codecarbon INFO @ 16:15:02] Energy consumed for All CPU : 0.000004 kWh
# [codecarbon INFO @ 16:15:02] 0.000010 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0333342552185059' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.333392370545122e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3137466009021321e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# [codecarbon WARNING @ 16:15:02] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 16:15:02] [setup] RAM Tracking...
# [codecarbon INFO @ 16:15:02] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:15:04] We saw that you have a AMD Ryzen 5 7530U with Radeon Graphics but we don't know it. Please contact us.
# [codecarbon WARNING @ 16:15:04] We will use the default power consumption of 4 W per thread for your 12 CPU, so 48W.
# [codecarbon WARNING @ 16:15:04] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 16:15:04] CPU Model on constant consumption mode: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon WARNING @ 16:15:04] No CPU tracking mode found. Falling back on CPU load mode.
# [codecarbon INFO @ 16:15:04] [setup] GPU Tracking...
# [codecarbon INFO @ 16:15:04] No GPU found.
# [codecarbon INFO @ 16:15:04] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: cpu_load
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 16:15:04] >>> Tracker's metadata:
# [codecarbon INFO @ 16:15:04]   Platform system: Linux-6.8.0-60-generic-x86_64-with-glibc2.39
# [codecarbon INFO @ 16:15:04]   Python version: 3.12.3
# [codecarbon INFO @ 16:15:04]   CodeCarbon version: 3.0.1
# [codecarbon INFO @ 16:15:04]   Available RAM : 13.501 GB
# [codecarbon INFO @ 16:15:04]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 16:15:04]   CPU model: AMD Ryzen 5 7530U with Radeon Graphics
# [codecarbon INFO @ 16:15:04]   GPU count: None
# [codecarbon INFO @ 16:15:04]   GPU model: None
# [codecarbon INFO @ 16:15:07] Emissions data (if any) will be saved to file /home/milou/Documents/afstudeerproject/performance/results/uci_codecarbon.csv
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:140: UserWarning:
# If you use a VPN, you may have problems with identifying your country by IP.
# It is recommended to disable VPN or
# manually set up the ISO-Alpha-2 code of your country during initialization of the Tracker() class.
# You can find the ISO-Alpha-2 code of your country here: https://www.iban.com/country-codes
#
#   warnings.warn(
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/tools/tools_gpu.py:42: NoGPUWarning: There is no any available GPU devices or your GPU is not supported by Nvidia library!
# The tracker will consider CPU usage only
#   warnings.warn(
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27291, number of used features: 6
# [LightGBM] [Info] Start training from score 1.088350
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27310, number of used features: 6
# [LightGBM] [Info] Start training from score 0.123707
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27304, number of used features: 6
# [LightGBM] [Info] Start training from score 240.844237
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27360, number of used features: 6
# [LightGBM] [Info] Start training from score 4.622085
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27344, number of used features: 6
# [LightGBM] [Info] Start training from score 1.123250
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27446, number of used features: 6
# [LightGBM] [Info] Start training from score 1.296233
# [codecarbon INFO @ 16:15:09] Energy consumed for RAM : 0.000006 kWh. RAM Power : 10.0 W
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27346, number of used features: 6
# [LightGBM] [Info] Start training from score 6.474420
# [codecarbon INFO @ 16:15:10] Delta energy consumed for CPU with cpu_load : 0.000008 kWh, power : 12.264000000000001 W
# [codecarbon INFO @ 16:15:10] Energy consumed for All CPU : 0.000008 kWh
# [codecarbon INFO @ 16:15:10] 0.000014 kWh of electricity used since the beginning.
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.340482473373413' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.4357969533450616e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7482229878614955e-08' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array
# /home/milou/Documents/afstudeerproject/.venv/lib/python3.12/site-packages/eco2ai/emission_track.py:515: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   attributes_dataframe.loc[row_index] = attributes_array

# %%
features = [
    "Global_reactive_power",
    "Voltage",
    "Global_intensity",
    "Sub_metering_1",
    "Sub_metering_2",
    "Sub_metering_3",
]

fig, axs = plt.subplots(3, 3, figsize=(18, 14))
axs = axs.flatten()
forecasting = {}

for i, (name, df_imputed) in enumerate(imputed.items()):
    X = df_imputed[features]
    y = df_imputed[target]

    X_train, X_test, y_train, y_test = fc.split_data(X, y, train_size=0.8)

    model = LGBMRegressor(force_col_wise=True)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    valid = (~np.isnan(y_test)) & (~np.isnan(y_pred))
    forecasting[name] = mean_absolute_error(y_test[valid], y_pred[valid])

    axs[i].scatter(y_test, y_pred, alpha=0.5, label="Predicted", color="b")
    axs[i].plot(
        [y_test.min(), y_test.max()],
        [y_test.min(), y_test.max()],
        "r--",
        lw=2,
        label="Perfect Prediction",
    )
    axs[i].set_xlabel("Actual Values (Global Active Power)")
    axs[i].set_ylabel("Predicted Values (Global Active Power)")
    axs[i].set_title(f"{name}")
    axs[i].legend()


for j in range(len(imputed), len(axs)):
    axs[j].axis("off")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.suptitle("Actual vs Predicted Values per Method")
plt.savefig("performance/figures/uci/forecasting.png")
plt.show()
# Out:
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27671, number of used features: 6
# [LightGBM] [Info] Start training from score 1.116707
# [LightGBM] [Info] Total Bins 1527
# [LightGBM] [Info] Number of data points in the train set: 27671, number of used features: 6
# [LightGBM] [Info] Start training from score 1.118719
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27671, number of used features: 6
# [LightGBM] [Info] Start training from score 1.117713
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27671, number of used features: 6
# [LightGBM] [Info] Start training from score 1.109505
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27671, number of used features: 6
# [LightGBM] [Info] Start training from score 1.063650
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27671, number of used features: 6
# [LightGBM] [Info] Start training from score 1.110719
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27671, number of used features: 6
# [LightGBM] [Info] Start training from score 1.111491

# %%
# Save to CSV files for plotting later
df_performance = pd.DataFrame.from_dict(performance, orient="index").reset_index()
df_performance.columns = ["method", "MAE", "NRMSE"]
df_performance["dataset"] = "uci"
df_performance.to_csv("performance/results/uci_performance.csv")

df_forecasting = pd.DataFrame.from_dict(forecasting, orient="index").reset_index()
df_forecasting.columns = ["method", "MAE"]
df_forecasting["dataset"] = "uci"
df_forecasting.to_csv("performance/results/uci_forecasting.csv")

# %%
df_performance = pd.read_csv("performance/results/uci_forecasting.csv")
df_performance["MAE"] = pd.to_numeric(df_performance["MAE"], errors="coerce")
df_plot = df_performance.groupby("method")[["MAE"]].mean()

fig, ax = plt.subplots(figsize=(8, 4))

df_plot["MAE"].plot(kind="bar", ax=ax, color="skyblue")
plt.title("MAE by Imputation Method")
plt.ylabel("Mean Absolute Error")
plt.tick_params(axis="x", rotation=90)

plt.tight_layout()
plt.savefig(f"performance/figures/uci/forecasting_mae.png")

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
df_performance.set_index("method", inplace=True)

df_performance["MAE"].plot(kind="bar", ax=axs[0], color="skyblue")
axs[0].set_title("MAE by Imputation Method")
axs[0].set_ylabel("Mean Absolute Error")
axs[0].tick_params(axis="x", rotation=90)

df_performance["NRMSE"].plot(kind="bar", ax=axs[1], color="salmon")
axs[1].set_title("NRMSE by Imputation Method")
axs[1].set_ylabel("Normalized RMSE")
axs[1].tick_params(axis="x", rotation=90)

plt.tight_layout()
plt.savefig("performance/figures/uci/error.png")
plt.show()

# %%
df_emission = pd.read_csv("performance/results/uci_codecarbon.csv")
df_emission_cleaned = df_emission[["project_name", "duration", "emissions", "energy_consumed"]]
df_emission_cleaned = df_emission_cleaned.set_index("project_name").sort_values("duration")

fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[0].bar(df_emission_cleaned.index, df_emission_cleaned["duration"])
axs[0].set_title("Runtime (s)")
axs[0].set_yscale("log")
axs[0].set_ylabel("Runtime (seconds)")
axs[0].tick_params(axis='x', rotation=90)

axs[1].bar(df_emission_cleaned.index, df_emission_cleaned["emissions"])
axs[1].set_title("CO₂ Emissions (kg)")
axs[1].set_yscale("log")
axs[1].set_ylabel("CO₂ Emissions (kg)")
axs[1].tick_params(axis='x', rotation=90)

axs[2].bar(df_emission_cleaned.index, df_emission_cleaned["energy_consumed"])
axs[2].set_title("Energy Consumed (kWh)")
axs[2].set_yscale("log")
axs[2].set_ylabel("Energy Consumed (kWh)")
axs[2].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.savefig("performance/figures/uci/emissions_codecarbon.png")
plt.show()

# %%
# Plot eco2ai performance
df_emission = pd.read_csv("performance/results/uci_eco2ai.csv")
df_emission_cleaned = df_emission[["project_name", "duration(s)", "CO2_emissions(kg)", "power_consumption(kWh)"]]
df_emission_cleaned = df_emission_cleaned.set_index("project_name").sort_values("duration(s)")

fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[0].bar(df_emission_cleaned.index, df_emission_cleaned["duration(s)"])
axs[0].set_title("Runtime (s)")
axs[0].set_ylabel("Runtime (s)")
axs[0].set_yscale("log")
axs[0].tick_params(axis='x', rotation=90)

axs[1].bar(df_emission_cleaned.index, df_emission_cleaned["CO2_emissions(kg)"])
axs[1].set_title("CO₂ Emissions (kg)")
axs[1].set_ylabel("CO₂ Emissions (kg)")
axs[1].set_yscale("log")
axs[1].tick_params(axis='x', rotation=90)

axs[2].bar(df_emission_cleaned.index, df_emission_cleaned["power_consumption(kWh)"])
axs[2].set_title("Energy Consumed (kWh)")
axs[2].set_ylabel("Energy Consumed (kWh)")
axs[2].set_yscale("log")
axs[2].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.savefig("performance/figures/uci/emissions_eco2ai.png")
plt.show()
